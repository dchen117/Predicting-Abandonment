# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
# Out:
# /tmp/ipykernel_67/3338272293.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
one_df = pd.read_excel('project_680..999.xlsx')
two_df = pd.read_excel('project_1000-4999.xlsx')
three_df = pd.read_excel('project_5000Up.xlsx')
four_df = pd.read_excel('project_100..177.xlsx')
five_df = pd.read_excel('project_178..679.xlsx')
#project_list = one_df['Project'].tolist() + two_df['Project'].tolist() + three_df['Project'].tolist()
size_list = one_df['Size'].tolist() + two_df['Size'].tolist() + three_df['Size'].tolist() + four_df['Size'].tolist() + five_df['Size'].tolist()
size_list = sorted(size_list)

# %%
#for i in range(len(size_list)):
    #size_list[i] = size_list[i]/1000
# np.histogram(sizes)
plt.hist(size_list[:int(len(size_list)/2)], bins=100)
plt.show()

# %%
print("Range for Plot above:",size_list[0],"-",size_list[int(len(size_list)/2)-1])
print("Number of data points above:", len(size_list[:int(len(size_list)/2)]))
# Out:
# Range for Plot above: 0 - 1949
# Number of data points above: 172448

# %%
plt.hist(size_list[int(len(size_list)/2):-10000], bins=100)
plt.show()

# %%
print("Range for Plot above:",size_list[int(len(size_list)/2)],"-",size_list[-10001])
print("Number of data points above:", len(size_list[int(len(size_list)/2):-10000]))
# Out:
# Range for Plot above: 1949 - 271252
# Number of data points above: 162449

# %%
plt.hist(size_list[-10000:-500], bins=100)
plt.show()

# %%
print("Range for Plot above:",size_list[-10000],"-",size_list[-501])
print("Number of data points above:", len(size_list[-10000:-500]))
# Out:
# Range for Plot above: 271271 - 3404945
# Number of data points above: 9500

# %%
plt.hist(size_list[-500:-100], bins=100)
plt.show()

# %%
print("Range for Plot above:",size_list[-500],"-",size_list[-101])
print("Number of data points above:", len(size_list[-500:-100]))
# Out:
# Range for Plot above: 3417564 - 10964625
# Number of data points above: 400

# %%
plt.hist(size_list[-100:], bins=100)
plt.show()

# %%
print("Range for Plot above:",size_list[-100],"-",size_list[-1])
print("Number of data points above:", len(size_list[-100:]))
print("Two Biggest Outliers:", size_list[-1],"and",size_list[-2])
# Out:
# Range for Plot above: 10988615 - 105078627
# Number of data points above: 100
# Two Biggest Outliers: 105078627 and 104965069

# %% [markdown]
# # Ugly Histogram
# The reason why we split up the histograms to show distributions across a certain amount

# %%
plt.hist(size_list, bins=100)
plt.show()
